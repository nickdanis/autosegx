# %% [markdown]
# # Towards a strong generative capacity for phonology
#
# **WUSTL Brownbag talk, November 10, 2023**
#
# python supplement
#
# Nick Danis / nsdanis@wustl.edu / http://nickdanis.com / https://github.com/nickdanis/autosegx

# %%
import autosegx as ax

unified_f = {
    'p' : {('rt','Cpl'), ('Cpl','+lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    't' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','+cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'k' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','+dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'pw' : {('rt','Cpl'), ('Cpl','+lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','+lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'tw' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','+cor1'), ('rt','Vpl'), ('Vpl','+lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'kw' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','+dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','+lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'pj' : {('rt','Cpl'), ('Cpl','+lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','+cor2')},
    'tj' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','+cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','+cor2')},
    'kj' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','+dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','+cor2')},
    'pɣ' : {('rt','Cpl'), ('Cpl','+lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','+dors2'), ('Vpl','-cor2')},
    'tɣ' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','+cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','+dors2'), ('Vpl','-cor2')},
    'kɣ' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','+dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','+dors2'), ('Vpl','-cor2')},
    'kp' : {('rt','Cpl'), ('Cpl','+lab1'), ('Cpl','+dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'tp' : {('rt','Cpl'), ('Cpl','+lab1'), ('Cpl','-dors1'), ('Cpl','+cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'kt' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','+dors1'), ('Cpl','+cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'y' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','+lab2'), ('Vpl','-dors2'), ('Vpl','+cor2')}, 
    'ʉ' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','+lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'u' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','+lab2'), ('Vpl','+dors2'), ('Vpl','-cor2')},
    'i' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','+cor2')},
    'ɨ' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'ɯ' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','+dors2'), ('Vpl','-cor2')},
}

v_features_f = {
    'p' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    't' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'k' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'pw' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','-frnt')},
    'tw' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','-frnt')},
    'kw' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','-frnt')},
    'pj' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','+frnt')},
    'tj' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','+frnt')},
    'kj' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','+frnt')},
    'pɣ' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','+bck'), ('rt','-frnt')},
    'tɣ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','+bck'), ('rt','-frnt')},
    'kɣ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','+bck'), ('rt','-frnt')},
    'kp' : {('rt','Pl'), ('Pl','+lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'tp' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'kt' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'y' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','+frnt')}, 
    'ʉ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','-frnt')},
    'u' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','+bck'), ('rt','-frnt')},
    'i' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','+frnt')},
    'ɨ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'ɯ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','+bck'), ('rt','-frnt')},
}

unified = ax.Theory(unified_f, name="unified")
v_features = ax.Theory(v_features_f, name="v-features")

report = ax.Comparison([unified, v_features])

# %%
unified.segments['kw'].gv()

# %%
v_features.segments['kw'].gv()

# %%
report.results(verbose = 2, shared = True)
# Out:
# The theories are NOT natural class preserving.
#
# 6 natural class(es) unique to unified.
# 	1. [ i k kj kp kt kw p pj pw pɣ t tj tp tw tɣ u y ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1) -dors
# 	2. [ i k kj kp kt kw kɣ p pj pw pɣ t tp tw tɣ u y ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1) -cor
# 	3. [ i kj kt pj t tj tp tw tɣ y ]
# 		Defining factors:
# 		(1) +cor
# 	4. [ i k kj kp kt kw kɣ p pj pɣ t tj tp tw tɣ u y ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1) -lab
# 	5. [ k kj kp kt kw kɣ pɣ tɣ u ɯ ]
# 		Defining factors:
# 		(1) +dors
# 	6. [ kp kw p pj pw pɣ tp tw u y ʉ ]
# 		Defining factors:
# 		(1) +lab
#
# 0 natural class(es) unique to v-features.
#
# 238 natural class(es) shared.
# 	1. [ pj ]
# 		Defining factors:
# 		(1-1) Vpl -> +cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-3) Vpl -> +cor, Vpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-4) Vpl -> +cor, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-5) Vpl -> +cor, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-6) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-7) Vpl -> -lab, Vpl -> +cor, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-8) Vpl -> -lab, Vpl -> +cor, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-9) Vpl -> +cor, Vpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-10) Vpl -> +cor, Vpl -> -dors, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-11) Vpl -> +cor, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-12) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-13) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-14) Vpl -> -lab, Vpl -> +cor, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-15) Vpl -> +cor, Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-16) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, rt -> Pl, rt -> +frnt
# 		(2-2) Pl -> -dors, Pl -> +lab, rt -> Pl, rt -> +frnt
# 		(2-3) Pl -> +lab, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-4) Pl -> +lab, rt -> -bck, rt -> Pl, rt -> +frnt
# 		(2-5) Pl -> -cor, Pl -> +lab, rt -> Pl, rt -> +frnt
# 		(2-6) Pl -> -dors, Pl -> +lab, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-7) Pl -> -dors, Pl -> +lab, rt -> -bck, rt -> Pl, rt -> +frnt
# 		(2-8) Pl -> -dors, Pl -> -cor, Pl -> +lab, rt -> Pl, rt -> +frnt
# 		(2-9) Pl -> +lab, rt -> -bck, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-10) Pl -> -cor, Pl -> +lab, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-11) Pl -> -cor, Pl -> +lab, rt -> -bck, rt -> Pl, rt -> +frnt
# 		(2-12) Pl -> -dors, Pl -> +lab, rt -> -bck, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-13) Pl -> -dors, Pl -> -cor, Pl -> +lab, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-14) Pl -> -dors, Pl -> -cor, Pl -> +lab, rt -> -bck, rt -> Pl, rt -> +frnt
# 		(2-15) Pl -> -cor, Pl -> +lab, rt -> -bck, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-16) Pl -> -dors, Pl -> -cor, Pl -> +lab, rt -> -bck, rt -> -rnd, rt -> Pl, rt -> +frnt
# 	2. [ kp p pw tp ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, rt -> -frnt, rt -> -bck, rt -> Pl
# 	3. [ p pj pɣ tp ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +lab, rt -> -rnd, rt -> Pl
# 	4. [ kp p pj pw pɣ tp ]
# 		Defining factors:
# 		(1-1) Cpl -> +lab
# 		(1-2) Cpl -> +lab, rt -> Cpl
# 		(1-3) Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) +lab
# 		(2-2) Pl -> +lab
# 		(2-3) rt -> Pl, Pl -> +lab
# 	5. [ i kj pj ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +cor, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -cor, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-2) Pl -> -cor, rt -> -bck, rt -> -rnd, rt -> Pl, rt -> +frnt
# 	6. [ kp p pj pɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, Pl -> -cor, rt -> -rnd, rt -> Pl
# 	7. [ kw y ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> -cor, rt -> -bck, rt -> +rnd, rt -> Pl
# 	8. [ i ɨ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, Pl -> -lab, rt -> -bck, rt -> -rnd, rt -> Pl
# 	9. [ p pɣ t tp tɣ ɨ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -cor, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, rt -> -frnt, rt -> -rnd, rt -> Pl
# 	10. [ i k kj kp kt p pj t tj tp ɨ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors
# 		(1-2) Vpl -> -lab, Vpl -> -dors, rt -> Vpl
# 		(1-3) Vpl -> -lab, Vpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) rt -> -bck, rt -> -rnd
# 		(2-2) rt -> -bck, rt -> -rnd, rt -> Pl
# 	11. [ k kt kw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> +dors, rt -> -frnt, rt -> -bck, rt -> Pl
# 	12. [ k kp kt kɣ p pɣ t tp tɣ ɨ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -cor
# 		(1-2) Vpl -> -lab, Vpl -> -cor, rt -> Vpl
# 		(1-3) Vpl -> -lab, Vpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) rt -> -frnt, rt -> -rnd
# 		(2-2) rt -> -frnt, rt -> -rnd, rt -> Pl
# 	13. [ i k kj kt kw t tj tw y ɨ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, rt -> -bck, rt -> Pl
# 	14. [ i p pj t tj tp ɨ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, rt -> -bck, rt -> -rnd, rt -> Pl
# 	15. [ kw pw tw u y ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab
# 		(1-2) Vpl -> +lab, rt -> Vpl
# 		(1-3) Vpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) +rnd
# 		(2-2) rt -> +rnd
# 		(2-3) rt -> +rnd, rt -> Pl
# 	16. [ k kj kp kt kw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +dors, rt -> -bck, rt -> Pl
# 	17. [ k kw kɣ u ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> Pl
# 	18. [ kp p pɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -cor, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> -rnd, rt -> Pl
# 	19. [ kt t tj tp tw tɣ ]
# 		Defining factors:
# 		(1-1) Cpl -> +cor
# 		(1-2) Cpl -> +cor, rt -> Cpl
# 		(1-3) Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(2-1) +cor
# 		(2-2) Pl -> +cor
# 		(2-3) rt -> Pl, Pl -> +cor
# 	20. [ p pɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> -rnd, rt -> Pl
# 	21. [ kt t tw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor, Cpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, Pl -> -lab, rt -> -frnt, rt -> -bck, rt -> Pl
# 	22. [ p ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> -rnd, rt -> Pl
# 	23. [ pw ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> +lab, Vpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-3) Vpl -> +lab, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-4) Vpl -> +lab, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-5) Vpl -> +lab, Vpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-6) Vpl -> +lab, Vpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-7) Vpl -> +lab, Vpl -> -dors, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-8) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-9) Vpl -> +lab, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-10) Vpl -> +lab, Vpl -> -cor, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-11) Vpl -> +lab, Vpl -> -cor, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-12) Vpl -> +lab, Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-13) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-14) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-15) Vpl -> +lab, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-16) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, rt -> +rnd, rt -> Pl
# 		(2-2) Pl -> -dors, Pl -> +lab, rt -> +rnd, rt -> Pl
# 		(2-3) Pl -> +lab, rt -> -bck, rt -> +rnd, rt -> Pl
# 		(2-4) Pl -> +lab, Pl -> -cor, rt -> +rnd, rt -> Pl
# 		(2-5) Pl -> +lab, rt -> -frnt, rt -> +rnd, rt -> Pl
# 		(2-6) Pl -> -dors, Pl -> +lab, rt -> -bck, rt -> +rnd, rt -> Pl
# 		(2-7) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> +rnd, rt -> Pl
# 		(2-8) Pl -> -dors, Pl -> +lab, rt -> -frnt, rt -> +rnd, rt -> Pl
# 		(2-9) Pl -> +lab, Pl -> -cor, rt -> -bck, rt -> +rnd, rt -> Pl
# 		(2-10) Pl -> +lab, rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# 		(2-11) Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> +rnd, rt -> Pl
# 		(2-12) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> -bck, rt -> +rnd, rt -> Pl
# 		(2-13) Pl -> -dors, Pl -> +lab, rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# 		(2-14) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> +rnd, rt -> Pl
# 		(2-15) Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# 		(2-16) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# 	24. [ kt t tj tw tɣ ]
# 		Defining factors:
# 		(1-1) Cpl -> +cor, Cpl -> -lab
# 		(1-2) Cpl -> +cor, Cpl -> -lab, rt -> Cpl
# 		(1-3) Cpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, Pl -> -lab
# 		(2-2) Pl -> +cor, Pl -> -lab, rt -> Pl
# 	25. [ kw pw y ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -cor, rt -> -bck, rt -> +rnd, rt -> Pl
# 	26. [ k kt ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> +dors, rt -> -frnt, rt -> -rnd, rt -> -bck, rt -> Pl
# 	27. [ i p pj pɣ ɨ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, rt -> -rnd, rt -> Pl
# 	28. [ kɣ tɣ u ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> +dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> +dors, Vpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, rt -> +bck, rt -> Pl
# 		(2-2) Pl -> -lab, rt -> -frnt, rt -> +bck, rt -> Pl
# 	29. [ kɣ u ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> +dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> +dors, Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> -cor, rt -> +bck, rt -> Pl
# 		(2-2) Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> Pl
# 	30. [ k kp ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> -rnd, rt -> -bck, rt -> Pl
# 	31. [ i kj pj tj ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +cor
# 		(1-2) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors
# 		(1-3) Vpl -> -lab, Vpl -> +cor, rt -> Vpl
# 		(1-4) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, rt -> Vpl
# 		(1-5) Vpl -> -lab, Vpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-6) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) rt -> -rnd, rt -> +frnt
# 		(2-2) rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-3) rt -> -bck, rt -> -rnd, rt -> +frnt
# 		(2-4) rt -> -bck, rt -> -rnd, rt -> Pl, rt -> +frnt
# 	32. [ kw tw ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# 	33. [ tw u y ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, rt -> +rnd, rt -> Pl
# 	34. [ kw u y ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> -cor, rt -> +rnd, rt -> Pl
# 	35. [ kt ]
# 		Defining factors:
# 		(1-1) Cpl -> +cor, Cpl -> +dors
# 		(1-2) Cpl -> +cor, Cpl -> -lab, Cpl -> +dors
# 		(1-3) Cpl -> +cor, Cpl -> +dors, rt -> Cpl
# 		(1-4) Cpl -> +cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-5) Cpl -> +cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl
# 		(1-6) Vpl -> -lab, Cpl -> +cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-7) Cpl -> +cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-8) Vpl -> -dors, Cpl -> +cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-9) Vpl -> -cor, Cpl -> +cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-10) Vpl -> -lab, Cpl -> +cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-11) Vpl -> -lab, Vpl -> -dors, Cpl -> +cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-12) Vpl -> -lab, Vpl -> -cor, Cpl -> +cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-13) Vpl -> -dors, Cpl -> +cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-14) Vpl -> -cor, Cpl -> +cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-15) Vpl -> -dors, Vpl -> -cor, Cpl -> +cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-16) Vpl -> -lab, Vpl -> -dors, Cpl -> +cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-17) Vpl -> -lab, Vpl -> -cor, Cpl -> +cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-18) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> +cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-19) Vpl -> -dors, Vpl -> -cor, Cpl -> +cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-20) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> +cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, Pl -> +dors
# 		(2-2) Pl -> +cor, Pl -> +dors, rt -> Pl
# 		(2-3) Pl -> +cor, Pl -> -lab, Pl -> +dors
# 		(2-4) Pl -> +cor, Pl -> +dors, rt -> -rnd, rt -> Pl
# 		(2-5) Pl -> +cor, Pl -> +dors, rt -> -bck, rt -> Pl
# 		(2-6) Pl -> +cor, Pl -> -lab, Pl -> +dors, rt -> Pl
# 		(2-7) Pl -> +cor, Pl -> +dors, rt -> -frnt, rt -> Pl
# 		(2-8) Pl -> +cor, Pl -> +dors, rt -> -rnd, rt -> -bck, rt -> Pl
# 		(2-9) Pl -> +cor, Pl -> -lab, Pl -> +dors, rt -> -rnd, rt -> Pl
# 		(2-10) Pl -> +cor, Pl -> +dors, rt -> -frnt, rt -> -rnd, rt -> Pl
# 		(2-11) Pl -> +cor, Pl -> -lab, Pl -> +dors, rt -> -bck, rt -> Pl
# 		(2-12) Pl -> +cor, Pl -> +dors, rt -> -frnt, rt -> -bck, rt -> Pl
# 		(2-13) Pl -> +cor, Pl -> -lab, Pl -> +dors, rt -> -frnt, rt -> Pl
# 		(2-14) Pl -> +cor, Pl -> -lab, Pl -> +dors, rt -> -rnd, rt -> -bck, rt -> Pl
# 		(2-15) Pl -> +cor, Pl -> +dors, rt -> -frnt, rt -> -rnd, rt -> -bck, rt -> Pl
# 		(2-16) Pl -> +cor, Pl -> -lab, Pl -> +dors, rt -> -frnt, rt -> -rnd, rt -> Pl
# 		(2-17) Pl -> +cor, Pl -> -lab, Pl -> +dors, rt -> -frnt, rt -> -bck, rt -> Pl
# 		(2-18) Pl -> +cor, Pl -> -lab, Pl -> +dors, rt -> -frnt, rt -> -rnd, rt -> -bck, rt -> Pl
# 	36. [ p pj pw tp ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +lab, rt -> -bck, rt -> Pl
# 	37. [ kt t tɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -cor, Cpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, Pl -> -lab, rt -> -frnt, rt -> -rnd, rt -> Pl
# 	38. [ kw pw tw u ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -cor
# 		(1-2) Vpl -> +lab, Vpl -> -cor, rt -> Vpl
# 		(1-3) Vpl -> +lab, Vpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) rt -> -frnt, rt -> +rnd
# 		(2-2) rt -> -frnt, rt -> +rnd, rt -> Pl
# 	39. [ kt t tj ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Cpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, Pl -> -lab, rt -> -rnd, rt -> -bck, rt -> Pl
# 	40. [ u y ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, Pl -> -lab, rt -> +rnd, rt -> Pl
# 	41. [ kp ]
# 		Defining factors:
# 		(1-1) Cpl -> +lab, Cpl -> +dors
# 		(1-2) Cpl -> -cor, Cpl -> +lab, Cpl -> +dors
# 		(1-3) Cpl -> +lab, Cpl -> +dors, rt -> Cpl
# 		(1-4) Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-5) Cpl -> -cor, Cpl -> +lab, Cpl -> +dors, rt -> Cpl
# 		(1-6) Vpl -> -lab, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-7) Vpl -> -dors, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-8) Cpl -> -cor, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-9) Vpl -> -cor, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-10) Vpl -> -lab, Vpl -> -dors, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-11) Vpl -> -lab, Cpl -> -cor, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-12) Vpl -> -lab, Vpl -> -cor, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-13) Vpl -> -dors, Cpl -> -cor, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-14) Vpl -> -dors, Vpl -> -cor, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-15) Vpl -> -cor, Cpl -> -cor, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-16) Vpl -> -lab, Vpl -> -dors, Cpl -> -cor, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-17) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-18) Vpl -> -lab, Vpl -> -cor, Cpl -> -cor, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-19) Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-20) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, Cpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, Pl -> +dors
# 		(2-2) Pl -> +lab, Pl -> +dors, rt -> Pl
# 		(2-3) Pl -> +lab, Pl -> +dors, Pl -> -cor
# 		(2-4) Pl -> +lab, Pl -> +dors, rt -> -rnd, rt -> Pl
# 		(2-5) Pl -> +lab, Pl -> +dors, rt -> -bck, rt -> Pl
# 		(2-6) Pl -> +lab, Pl -> +dors, Pl -> -cor, rt -> Pl
# 		(2-7) Pl -> +lab, Pl -> +dors, rt -> -frnt, rt -> Pl
# 		(2-8) Pl -> +lab, Pl -> +dors, rt -> -bck, rt -> -rnd, rt -> Pl
# 		(2-9) Pl -> +lab, Pl -> +dors, Pl -> -cor, rt -> -rnd, rt -> Pl
# 		(2-10) Pl -> +lab, Pl -> +dors, rt -> -frnt, rt -> -rnd, rt -> Pl
# 		(2-11) Pl -> +lab, Pl -> +dors, Pl -> -cor, rt -> -bck, rt -> Pl
# 		(2-12) Pl -> +lab, Pl -> +dors, rt -> -frnt, rt -> -bck, rt -> Pl
# 		(2-13) Pl -> +lab, Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> Pl
# 		(2-14) Pl -> +lab, Pl -> +dors, Pl -> -cor, rt -> -bck, rt -> -rnd, rt -> Pl
# 		(2-15) Pl -> +lab, Pl -> +dors, rt -> -frnt, rt -> -bck, rt -> -rnd, rt -> Pl
# 		(2-16) Pl -> +lab, Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> -rnd, rt -> Pl
# 		(2-17) Pl -> +lab, Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> Pl
# 		(2-18) Pl -> +lab, Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> -rnd, rt -> Pl
# 	42. [ i k kj kw kɣ u y ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1-1) Cpl -> -cor, Cpl -> -lab
# 		(1-2) Cpl -> -cor, Cpl -> -lab, rt -> Cpl
# 		(1-3) Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> -cor
# 		(2-2) Pl -> -lab, Pl -> -cor, rt -> Pl
# 	43. [ kp p pw pɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> Pl
# 	44. [ tw y ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -dors, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, rt -> -bck, rt -> +rnd, rt -> Pl
# 	45. [ t tj tw tɣ ]
# 		Defining factors:
# 		(1-1) Cpl -> -dors, Cpl -> +cor, Cpl -> -lab
# 		(1-2) Cpl -> -dors, Cpl -> +cor, Cpl -> -lab, rt -> Cpl
# 		(1-3) Cpl -> -dors, Cpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +cor, Pl -> -lab
# 		(2-2) Pl -> -dors, Pl -> +cor, Pl -> -lab, rt -> Pl
# 	46. [ kt t ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, Pl -> -lab, rt -> -frnt, rt -> -rnd, rt -> -bck, rt -> Pl
# 	47. [ kw pw tw ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor
# 		(1-2) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, rt -> Vpl
# 		(1-3) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) rt -> -frnt, rt -> -bck, rt -> +rnd
# 		(2-2) rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# 	48. [ t tp ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +cor, rt -> -frnt, rt -> -rnd, rt -> -bck, rt -> Pl
# 	49. [ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +dors, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, Pl -> -cor, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-2) Pl -> -dors, Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 	50. [ i p pj pw y ɨ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, rt -> -bck, rt -> Pl
# 	51. [ p pj pɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> -rnd, rt -> Pl
# 	52. [ i p pj pɣ t tj tp tɣ ɨ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, rt -> -rnd, rt -> Pl
# 	53. [ kt t tp tw tɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, rt -> -frnt, rt -> Pl
# 	54. [ t tw tɣ u ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, rt -> -frnt, rt -> Pl
# 	55. [ k kj kt ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> +dors, rt -> -rnd, rt -> -bck, rt -> Pl
# 	56. [ k kp kɣ p pɣ ɨ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -cor, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -cor, rt -> -frnt, rt -> -rnd, rt -> Pl
# 	57. [ kj ]
# 		Defining factors:
# 		(1-1) Vpl -> +cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-3) Vpl -> +cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-4) Vpl -> +cor, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-5) Vpl -> +cor, Vpl -> -dors, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-6) Vpl -> -lab, Vpl -> +cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-7) Vpl -> -lab, Vpl -> +cor, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-8) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-9) Vpl -> +cor, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-10) Vpl -> +cor, Vpl -> -dors, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-11) Vpl -> +cor, Vpl -> -dors, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-12) Vpl -> -lab, Vpl -> +cor, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-13) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-14) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-15) Vpl -> +cor, Vpl -> -dors, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-16) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +dors, rt -> Pl, rt -> +frnt
# 		(2-2) Pl -> +dors, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-3) Pl -> +dors, rt -> -bck, rt -> Pl, rt -> +frnt
# 		(2-4) Pl -> -lab, Pl -> +dors, rt -> Pl, rt -> +frnt
# 		(2-5) Pl -> -cor, Pl -> +dors, rt -> Pl, rt -> +frnt
# 		(2-6) Pl -> +dors, rt -> -rnd, rt -> -bck, rt -> Pl, rt -> +frnt
# 		(2-7) Pl -> -lab, Pl -> +dors, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-8) Pl -> -cor, Pl -> +dors, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-9) Pl -> -lab, Pl -> +dors, rt -> -bck, rt -> Pl, rt -> +frnt
# 		(2-10) Pl -> -cor, Pl -> +dors, rt -> -bck, rt -> Pl, rt -> +frnt
# 		(2-11) Pl -> -cor, Pl -> -lab, Pl -> +dors, rt -> Pl, rt -> +frnt
# 		(2-12) Pl -> -lab, Pl -> +dors, rt -> -rnd, rt -> -bck, rt -> Pl, rt -> +frnt
# 		(2-13) Pl -> -cor, Pl -> +dors, rt -> -rnd, rt -> -bck, rt -> Pl, rt -> +frnt
# 		(2-14) Pl -> -cor, Pl -> -lab, Pl -> +dors, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-15) Pl -> -cor, Pl -> -lab, Pl -> +dors, rt -> -bck, rt -> Pl, rt -> +frnt
# 		(2-16) Pl -> -cor, Pl -> -lab, Pl -> +dors, rt -> -rnd, rt -> -bck, rt -> Pl, rt -> +frnt
# 	58. [ kɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> +dors, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +dors, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-3) Vpl -> +dors, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-4) Vpl -> +dors, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-5) Vpl -> +dors, Vpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-6) Vpl -> -lab, Vpl -> +dors, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-7) Vpl -> -lab, Vpl -> +dors, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-8) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-9) Vpl -> +dors, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-10) Vpl -> +dors, Vpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-11) Vpl -> +dors, Vpl -> -cor, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-12) Vpl -> -lab, Vpl -> +dors, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-13) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-14) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-15) Vpl -> +dors, Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-16) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +dors, rt -> +bck, rt -> Pl
# 		(2-2) Pl -> +dors, Pl -> -cor, rt -> +bck, rt -> Pl
# 		(2-3) Pl -> +dors, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-4) Pl -> -lab, Pl -> +dors, rt -> +bck, rt -> Pl
# 		(2-5) Pl -> +dors, rt -> -frnt, rt -> +bck, rt -> Pl
# 		(2-6) Pl -> +dors, Pl -> -cor, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-7) Pl -> -lab, Pl -> +dors, Pl -> -cor, rt -> +bck, rt -> Pl
# 		(2-8) Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> Pl
# 		(2-9) Pl -> -lab, Pl -> +dors, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-10) Pl -> +dors, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-11) Pl -> -lab, Pl -> +dors, rt -> -frnt, rt -> +bck, rt -> Pl
# 		(2-12) Pl -> -lab, Pl -> +dors, Pl -> -cor, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-13) Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-14) Pl -> -lab, Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> Pl
# 		(2-15) Pl -> -lab, Pl -> +dors, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-16) Pl -> -lab, Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 	59. [ i y ]
# 		Defining factors:
# 		(1-1) Vpl -> +cor, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> +cor, Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, Pl -> -lab, rt -> Pl, rt -> +frnt
# 		(2-2) Pl -> -dors, Pl -> -cor, Pl -> -lab, rt -> -bck, rt -> Pl, rt -> +frnt
# 	60. [ pw ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# 	61. [ k kj kp ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +dors, Pl -> -cor, rt -> -rnd, rt -> -bck, rt -> Pl
# 	62. [ k kj kt kɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> +dors, rt -> -rnd, rt -> Pl
# 	63. [ y ]
# 		Defining factors:
# 		(1-1) Vpl -> +cor, Vpl -> +lab
# 		(1-2) Vpl -> +cor, Vpl -> +lab, Vpl -> -dors
# 		(1-3) Vpl -> +cor, Vpl -> +lab, rt -> Vpl
# 		(1-4) Vpl -> +cor, Vpl -> +lab, Vpl -> -dors, rt -> Vpl
# 		(1-5) Vpl -> +cor, Vpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-6) Vpl -> +cor, Vpl -> +lab, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-7) Vpl -> +cor, Vpl -> +lab, Vpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(1-8) Vpl -> +cor, Vpl -> +lab, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(1-9) Vpl -> +cor, Vpl -> +lab, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(1-10) Vpl -> +cor, Vpl -> +lab, Vpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-11) Vpl -> +cor, Vpl -> +lab, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-12) Vpl -> +cor, Vpl -> +lab, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-13) Vpl -> +cor, Vpl -> +lab, Vpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(1-14) Vpl -> +cor, Vpl -> +lab, Vpl -> -dors, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(1-15) Vpl -> +cor, Vpl -> +lab, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(1-16) Vpl -> +cor, Vpl -> +lab, Vpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-17) Vpl -> +cor, Vpl -> +lab, Vpl -> -dors, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-18) Vpl -> +cor, Vpl -> +lab, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-19) Vpl -> +cor, Vpl -> +lab, Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(1-20) Vpl -> +cor, Vpl -> +lab, Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) rt -> +rnd, rt -> +frnt
# 		(2-2) rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-3) rt -> -bck, rt -> +rnd, rt -> +frnt
# 		(2-4) Pl -> -dors, rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-5) rt -> -bck, rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-6) Pl -> -lab, rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-7) Pl -> -cor, rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-8) Pl -> -dors, rt -> -bck, rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-9) Pl -> -dors, Pl -> -lab, rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-10) Pl -> -dors, Pl -> -cor, rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-11) Pl -> -lab, rt -> -bck, rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-12) Pl -> -cor, rt -> -bck, rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-13) Pl -> -cor, Pl -> -lab, rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-14) Pl -> -dors, Pl -> -lab, rt -> -bck, rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-15) Pl -> -dors, Pl -> -cor, rt -> -bck, rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-16) Pl -> -dors, Pl -> -cor, Pl -> -lab, rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-17) Pl -> -cor, Pl -> -lab, rt -> -bck, rt -> +rnd, rt -> Pl, rt -> +frnt
# 		(2-18) Pl -> -dors, Pl -> -cor, Pl -> -lab, rt -> -bck, rt -> +rnd, rt -> Pl, rt -> +frnt
# 	64. [ pw u y ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, rt -> +rnd, rt -> Pl
# 	65. [ tp ]
# 		Defining factors:
# 		(1-1) Cpl -> +lab, Cpl -> +cor
# 		(1-2) Cpl -> -dors, Cpl -> +lab, Cpl -> +cor
# 		(1-3) Cpl -> +lab, Cpl -> +cor, rt -> Cpl
# 		(1-4) Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-5) Cpl -> -dors, Cpl -> +lab, Cpl -> +cor, rt -> Cpl
# 		(1-6) Vpl -> -lab, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-7) Vpl -> -dors, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-8) Cpl -> -dors, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-9) Vpl -> -cor, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-10) Vpl -> -lab, Vpl -> -dors, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-11) Vpl -> -lab, Cpl -> -dors, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-12) Vpl -> -lab, Vpl -> -cor, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-13) Vpl -> -dors, Cpl -> -dors, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-14) Vpl -> -dors, Vpl -> -cor, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-15) Vpl -> -cor, Cpl -> -dors, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-16) Vpl -> -lab, Vpl -> -dors, Cpl -> -dors, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-17) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-18) Vpl -> -lab, Vpl -> -cor, Cpl -> -dors, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-19) Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-20) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> +lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, Pl -> +lab
# 		(2-2) Pl -> -dors, Pl -> +cor, Pl -> +lab
# 		(2-3) Pl -> +cor, Pl -> +lab, rt -> Pl
# 		(2-4) Pl -> -dors, Pl -> +cor, Pl -> +lab, rt -> Pl
# 		(2-5) Pl -> +cor, Pl -> +lab, rt -> -rnd, rt -> Pl
# 		(2-6) Pl -> +cor, Pl -> +lab, rt -> -bck, rt -> Pl
# 		(2-7) Pl -> +cor, Pl -> +lab, rt -> -frnt, rt -> Pl
# 		(2-8) Pl -> -dors, Pl -> +cor, Pl -> +lab, rt -> -rnd, rt -> Pl
# 		(2-9) Pl -> -dors, Pl -> +cor, Pl -> +lab, rt -> -bck, rt -> Pl
# 		(2-10) Pl -> -dors, Pl -> +cor, Pl -> +lab, rt -> -frnt, rt -> Pl
# 		(2-11) Pl -> +cor, Pl -> +lab, rt -> -bck, rt -> -rnd, rt -> Pl
# 		(2-12) Pl -> +cor, Pl -> +lab, rt -> -frnt, rt -> -rnd, rt -> Pl
# 		(2-13) Pl -> +cor, Pl -> +lab, rt -> -frnt, rt -> -bck, rt -> Pl
# 		(2-14) Pl -> -dors, Pl -> +cor, Pl -> +lab, rt -> -bck, rt -> -rnd, rt -> Pl
# 		(2-15) Pl -> -dors, Pl -> +cor, Pl -> +lab, rt -> -frnt, rt -> -rnd, rt -> Pl
# 		(2-16) Pl -> -dors, Pl -> +cor, Pl -> +lab, rt -> -frnt, rt -> -bck, rt -> Pl
# 		(2-17) Pl -> +cor, Pl -> +lab, rt -> -frnt, rt -> -bck, rt -> -rnd, rt -> Pl
# 		(2-18) Pl -> -dors, Pl -> +cor, Pl -> +lab, rt -> -frnt, rt -> -bck, rt -> -rnd, rt -> Pl
# 	66. [ t ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +cor, Pl -> -lab, rt -> -frnt, rt -> -rnd, rt -> -bck, rt -> Pl
# 	67. [ k kj kp kt ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +dors, rt -> -rnd, rt -> -bck, rt -> Pl
# 	68. [ p pj tp ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +lab, rt -> -bck, rt -> -rnd, rt -> Pl
# 	69. [ i p pj pw pɣ u y ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1-1) Cpl -> -dors, Cpl -> -cor
# 		(1-2) Cpl -> -dors, Cpl -> -cor, rt -> Cpl
# 		(1-3) Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor
# 		(2-2) Pl -> -dors, Pl -> -cor, rt -> Pl
# 	70. [ i kj y ]
# 		Defining factors:
# 		(1-1) Vpl -> +cor, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> +cor, Vpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -cor, Pl -> -lab, rt -> Pl, rt -> +frnt
# 		(2-2) Pl -> -cor, Pl -> -lab, rt -> -bck, rt -> Pl, rt -> +frnt
# 	71. [ k kj kp kt kw kɣ ]
# 		Defining factors:
# 		(1-1) Cpl -> +dors
# 		(1-2) Cpl -> +dors, rt -> Cpl
# 		(1-3) Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) +dors
# 		(2-2) Pl -> +dors
# 		(2-3) rt -> Pl, Pl -> +dors
# 	72. [ ɨ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> -rnd, rt -> Pl
# 	73. [ i k kj kp kt kw p pj pw t tj tp tw y ɨ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors
# 		(1-2) Vpl -> -dors, rt -> Vpl
# 		(1-3) Vpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) -bck
# 		(2-2) rt -> -bck
# 		(2-3) rt -> -bck, rt -> Pl
# 	74. [ k kp kt p t tp ɨ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor
# 		(1-2) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, rt -> Vpl
# 		(1-3) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) rt -> -frnt, rt -> -bck, rt -> -rnd
# 		(2-2) rt -> -frnt, rt -> -bck, rt -> -rnd, rt -> Pl
# 	75. [ kw tw u y ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, rt -> +rnd, rt -> Pl
# 	76. [ i p pj ɨ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, rt -> -bck, rt -> -rnd, rt -> Pl
# 	77. [ k kj kt kw kɣ ]
# 		Defining factors:
# 		(1-1) Cpl -> -lab, Cpl -> +dors
# 		(1-2) Cpl -> -lab, Cpl -> +dors, rt -> Cpl
# 		(1-3) Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> +dors
# 		(2-2) Pl -> -lab, Pl -> +dors, rt -> Pl
# 	78. [ k kj kp kɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +dors, Pl -> -cor, rt -> -rnd, rt -> Pl
# 	79. [ pw tw u y ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, rt -> +rnd, rt -> Pl
# 	80. [ k kp p ɨ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> -rnd, rt -> Pl
# 	81. [ pɣ u ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> +dors, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> +dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, rt -> +bck, rt -> Pl
# 		(2-2) Pl -> -dors, Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> Pl
# 	82. [ kw pw tw y ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -dors
# 		(1-2) Vpl -> +lab, Vpl -> -dors, rt -> Vpl
# 		(1-3) Vpl -> +lab, Vpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) rt -> -bck, rt -> +rnd
# 		(2-2) rt -> -bck, rt -> +rnd, rt -> Pl
# 	83. [ p pw pɣ u ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, rt -> -frnt, rt -> Pl
# 	84. [ t tɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -cor, Cpl -> -dors, Cpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +cor, Pl -> -lab, rt -> -frnt, rt -> -rnd, rt -> Pl
# 	85. [ tɣ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +dors, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-2) Pl -> -dors, Pl -> -lab, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 	86. [ i pj y ]
# 		Defining factors:
# 		(1-1) Vpl -> +cor, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> +cor, Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, rt -> Pl, rt -> +frnt
# 		(2-2) Pl -> -dors, Pl -> -cor, rt -> -bck, rt -> Pl, rt -> +frnt
# 	87. [ kp p ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> -rnd, rt -> Pl
# 	88. [ i k kj kp kw p pj pw y ɨ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -cor, rt -> -bck, rt -> Pl
# 	89. [ pw u ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, rt -> -frnt, rt -> +rnd, rt -> Pl
# 	90. [ i k kj kp kw kɣ p pj pw pɣ u y ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1-1) Cpl -> -cor
# 		(1-2) Cpl -> -cor, rt -> Cpl
# 		(1-3) Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) -cor
# 		(2-2) Pl -> -cor
# 		(2-3) rt -> Pl, Pl -> -cor
# 	91. [ p ɨ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> -rnd, rt -> Pl
# 	92. [ p pj pw pɣ ]
# 		Defining factors:
# 		(1-1) Cpl -> -dors, Cpl -> -cor, Cpl -> +lab
# 		(1-2) Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl
# 		(1-3) Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +lab, Pl -> -cor
# 		(2-2) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> Pl
# 	93. [ k kp kt kw kɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +dors, rt -> -frnt, rt -> Pl
# 	94. [ k kp kt kɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +dors, rt -> -frnt, rt -> -rnd, rt -> Pl
# 	95. [ k kp kw kɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> Pl
# 	96. [ kw tw u ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, rt -> -frnt, rt -> +rnd, rt -> Pl
# 	97. [ i y ɨ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, Pl -> -lab, rt -> -bck, rt -> Pl
# 	98. [ i k kj kt t tj ɨ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, rt -> -rnd, rt -> -bck, rt -> Pl
# 	99. [ pw tw u ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -cor, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, rt -> -frnt, rt -> +rnd, rt -> Pl
# 	100. [ u ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> Pl
# 	101. [ k kɣ ɨ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> -rnd, rt -> Pl
# 	102. [ k kj ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> +dors, Pl -> -cor, rt -> -rnd, rt -> -bck, rt -> Pl
# 	103. [ k kɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> -rnd, rt -> Pl
# 	104. [ kp p pw pɣ tp ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, rt -> -frnt, rt -> Pl
# 	105. [ kw ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# 	106. [ kt t tp tw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, rt -> -frnt, rt -> -bck, rt -> Pl
# 	107. [ i p pj pw pɣ t tj tp tw tɣ u y ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1-1) Cpl -> -dors
# 		(1-2) Cpl -> -dors, rt -> Cpl
# 		(1-3) Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) -dors
# 		(2-2) Pl -> -dors
# 		(2-3) rt -> Pl, Pl -> -dors
# 	108. [ pɣ tɣ u ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> +dors, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> +dors, Vpl -> -cor, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, rt -> +bck, rt -> Pl
# 		(2-2) Pl -> -dors, rt -> -frnt, rt -> +bck, rt -> Pl
# 	109. [ i k kj kp kt kw kɣ p pj pw pɣ t tj tp tw tɣ u y ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl
# 		(1-2) Cpl
# 		(1-3) rt
# 		(1-4) rt -> Vpl
# 		(1-5) rt -> Cpl
# 		(1-6) rt -> Cpl, rt -> Vpl
# 		(2-1) Pl
# 		(2-2) rt
# 		(2-3) rt -> Pl
# 	110. [ t tp tw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +cor, rt -> -frnt, rt -> -bck, rt -> Pl
# 	111. [ kɣ tɣ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-2) Pl -> -lab, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 	112. [ k kw kɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> Pl
# 	113. [ i kj pj y ]
# 		Defining factors:
# 		(1-1) Vpl -> +cor, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> +cor, Vpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -cor, rt -> Pl, rt -> +frnt
# 		(2-2) Pl -> -cor, rt -> -bck, rt -> Pl, rt -> +frnt
# 	114. [ pɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> +dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-3) Vpl -> +dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-4) Vpl -> +dors, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-5) Vpl -> +dors, Vpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-6) Vpl -> -lab, Vpl -> +dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-7) Vpl -> -lab, Vpl -> +dors, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-8) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-9) Vpl -> +dors, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-10) Vpl -> +dors, Vpl -> -cor, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-11) Vpl -> +dors, Vpl -> -cor, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-12) Vpl -> -lab, Vpl -> +dors, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-13) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-14) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-15) Vpl -> +dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(1-16) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, rt -> +bck, rt -> Pl
# 		(2-2) Pl -> -dors, Pl -> +lab, rt -> +bck, rt -> Pl
# 		(2-3) Pl -> +lab, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-4) Pl -> +lab, Pl -> -cor, rt -> +bck, rt -> Pl
# 		(2-5) Pl -> +lab, rt -> -frnt, rt -> +bck, rt -> Pl
# 		(2-6) Pl -> -dors, Pl -> +lab, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-7) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> +bck, rt -> Pl
# 		(2-8) Pl -> -dors, Pl -> +lab, rt -> -frnt, rt -> +bck, rt -> Pl
# 		(2-9) Pl -> +lab, Pl -> -cor, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-10) Pl -> +lab, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-11) Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> Pl
# 		(2-12) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-13) Pl -> -dors, Pl -> +lab, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-14) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> Pl
# 		(2-15) Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-16) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 	115. [ kw ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> +lab, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-3) Vpl -> +lab, Vpl -> -dors, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-4) Vpl -> +lab, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-5) Vpl -> +lab, Vpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-6) Vpl -> +lab, Vpl -> -dors, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-7) Vpl -> +lab, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-8) Vpl -> +lab, Vpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-9) Vpl -> +lab, Vpl -> -dors, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-10) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-11) Vpl -> +lab, Vpl -> -cor, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-12) Vpl -> +lab, Vpl -> -dors, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-13) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-14) Vpl -> +lab, Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-15) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-16) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +dors, rt -> +rnd, rt -> Pl
# 		(2-2) Pl -> +dors, Pl -> -cor, rt -> +rnd, rt -> Pl
# 		(2-3) Pl -> +dors, rt -> -bck, rt -> +rnd, rt -> Pl
# 		(2-4) Pl -> -lab, Pl -> +dors, rt -> +rnd, rt -> Pl
# 		(2-5) Pl -> +dors, rt -> -frnt, rt -> +rnd, rt -> Pl
# 		(2-6) Pl -> +dors, Pl -> -cor, rt -> -bck, rt -> +rnd, rt -> Pl
# 		(2-7) Pl -> -lab, Pl -> +dors, Pl -> -cor, rt -> +rnd, rt -> Pl
# 		(2-8) Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> +rnd, rt -> Pl
# 		(2-9) Pl -> -lab, Pl -> +dors, rt -> -bck, rt -> +rnd, rt -> Pl
# 		(2-10) Pl -> +dors, rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# 		(2-11) Pl -> -lab, Pl -> +dors, rt -> -frnt, rt -> +rnd, rt -> Pl
# 		(2-12) Pl -> -lab, Pl -> +dors, Pl -> -cor, rt -> -bck, rt -> +rnd, rt -> Pl
# 		(2-13) Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# 		(2-14) Pl -> -lab, Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> +rnd, rt -> Pl
# 		(2-15) Pl -> -lab, Pl -> +dors, rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# ...
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +dors, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-2) Pl -> -dors, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 	166. [ k kw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> Pl
# 	167. [ kp p pw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> Pl
# 	168. [ i kj tj ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-2) Pl -> -lab, rt -> -rnd, rt -> -bck, rt -> Pl, rt -> +frnt
# 	169. [ p pw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> Pl
# 	170. [ i k kj kp p pj ɨ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -cor, rt -> -bck, rt -> -rnd, rt -> Pl
# 	171. [ k kp kt kw p pw t tp tw ɨ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor
# 		(1-2) Vpl -> -dors, Vpl -> -cor, rt -> Vpl
# 		(1-3) Vpl -> -dors, Vpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) rt -> -frnt, rt -> -bck
# 		(2-2) rt -> -frnt, rt -> -bck, rt -> Pl
# 	172. [ kt t tj tp tw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, rt -> -bck, rt -> Pl
# 	173. [ i k kj kw y ɨ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> -cor, rt -> -bck, rt -> Pl
# 	174. [ k ɨ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> -rnd, rt -> -bck, rt -> Pl
# 	175. [ i t tj tɣ ɨ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, rt -> -rnd, rt -> Pl
# 	176. [ kw pw u ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -cor, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -cor, rt -> -frnt, rt -> +rnd, rt -> Pl
# 	177. [ kw pw u y ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -cor, rt -> +rnd, rt -> Pl
# 	178. [ kɣ pɣ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -cor, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-2) Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 	179. [ p pw pɣ t tp tw tɣ u ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, rt -> -frnt, rt -> Pl
# 	180. [ p pw tp ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +lab, rt -> -frnt, rt -> -bck, rt -> Pl
# 	181. [ i pj tj ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +cor, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-2) Pl -> -dors, rt -> -bck, rt -> -rnd, rt -> Pl, rt -> +frnt
# 	182. [ i t tj tw y ɨ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, rt -> -bck, rt -> Pl
# 	183. [ tw ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# 	184. [ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# 	185. [ ɨ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> -rnd, rt -> Pl
# 	186. [ k kt kw kɣ t tw tɣ u ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, rt -> -frnt, rt -> Pl
# 	187. [ u ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> +rnd, rt -> Pl
# 	188. [ k kt kɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> +dors, rt -> -frnt, rt -> -rnd, rt -> Pl
# 	189. [ kɣ pɣ tɣ u ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> +dors
# 		(1-2) Vpl -> +dors, Vpl -> -cor
# 		(1-3) Vpl -> +dors, rt -> Vpl
# 		(1-4) Vpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-5) Vpl -> +dors, Vpl -> -cor, rt -> Vpl
# 		(1-6) Vpl -> +dors, Vpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) +bck
# 		(2-2) rt -> +bck
# 		(2-3) rt -> +bck, rt -> Pl
# 		(2-4) rt -> -frnt, rt -> +bck
# 		(2-5) rt -> -frnt, rt -> +bck, rt -> Pl
# 	190. [ kt t tp ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, rt -> -frnt, rt -> -rnd, rt -> -bck, rt -> Pl
# 	191. [ tɣ u ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> +dors, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> +dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, rt -> +bck, rt -> Pl
# 		(2-2) Pl -> -dors, Pl -> -lab, rt -> -frnt, rt -> +bck, rt -> Pl
# 	192. [ k kj kw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> -cor, Cpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> +dors, Pl -> -cor, rt -> -bck, rt -> Pl
# 	193. [ kt t tj tp tɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, rt -> -rnd, rt -> Pl
# 	194. [ i ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +cor, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, Pl -> -lab, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-2) Pl -> -dors, Pl -> -cor, Pl -> -lab, rt -> -bck, rt -> -rnd, rt -> Pl, rt -> +frnt
# 	195. [ t tj tp tw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> -dors, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +cor, rt -> -bck, rt -> Pl
# 	196. [ kp p pj tp ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, rt -> -bck, rt -> -rnd, rt -> Pl
# 	197. [ pw y ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, rt -> -bck, rt -> +rnd, rt -> Pl
# 	198. [ kt t tj tw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, Pl -> -lab, rt -> -bck, rt -> Pl
# 	199. [ p pɣ ɨ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, rt -> -frnt, rt -> -rnd, rt -> Pl
# 	200. [ i p pj pw t tj tp tw y ɨ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, rt -> -bck, rt -> Pl
# 	201. [ kp p pɣ tp ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, rt -> -frnt, rt -> -rnd, rt -> Pl
# 	202. [ k kj kp kt kɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +dors, rt -> -rnd, rt -> Pl
# 	203. [ k kp kw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, Cpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +dors, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> Pl
# 	204. [ p t tp ɨ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, rt -> -frnt, rt -> -bck, rt -> -rnd, rt -> Pl
# 	205. [ tw u ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -cor, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, rt -> -frnt, rt -> +rnd, rt -> Pl
# 	206. [ t tj tw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> -dors, Cpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +cor, Pl -> -lab, rt -> -bck, rt -> Pl
# 	207. [ i k kj kt kw kɣ t tj tw tɣ u y ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1-1) Cpl -> -lab
# 		(1-2) Cpl -> -lab, rt -> Cpl
# 		(1-3) Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) -lab
# 		(2-2) Pl -> -lab
# 		(2-3) rt -> Pl, Pl -> -lab
# 	208. [ p pj pw ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> -bck, rt -> Pl
# 	209. [ kt t tw tɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, Pl -> -lab, rt -> -frnt, rt -> Pl
# 	210. [ ɨ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> Pl
# 	211. [ pɣ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +dors, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-2) Pl -> -dors, Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 	212. [ pw tw ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# 	213. [ kp p tp ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, rt -> -frnt, rt -> -bck, rt -> -rnd, rt -> Pl
# 	214. [ t tw tɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> -dors, Cpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +cor, Pl -> -lab, rt -> -frnt, rt -> Pl
# 	215. [ p tp ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +lab, rt -> -frnt, rt -> -bck, rt -> -rnd, rt -> Pl
# 	216. [ k kt t ɨ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, rt -> -frnt, rt -> -rnd, rt -> -bck, rt -> Pl
# 	217. [ k kp kw p pw ɨ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> Pl
# 	218. [ kw u ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> +rnd, rt -> Pl
# 	219. [ kɣ pɣ tɣ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +dors
# 		(1-2) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor
# 		(1-3) Vpl -> -lab, Vpl -> +dors, rt -> Vpl
# 		(1-4) Vpl -> -lab, Vpl -> +dors, rt -> Cpl, rt -> Vpl
# 		(1-5) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, rt -> Vpl
# 		(1-6) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) rt -> +bck, rt -> -rnd
# 		(2-2) rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-3) rt -> -frnt, rt -> +bck, rt -> -rnd
# 		(2-4) rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 	220. [ kp p pj pɣ tp ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +lab, rt -> -rnd, rt -> Pl
# 	221. [ i k kj kɣ ɨ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> -cor, rt -> -rnd, rt -> Pl
# 	222. [ i k kj ɨ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> -cor, rt -> -rnd, rt -> -bck, rt -> Pl
# 	223. [ i tj ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +cor, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, Cpl -> -dors, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-2) Pl -> -dors, Pl -> -lab, rt -> -rnd, rt -> -bck, rt -> Pl, rt -> +frnt
# 	224. [ p pw pɣ tp ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> -dors, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +lab, rt -> -frnt, rt -> Pl
# 	225. [ k kp kt kw kɣ p pw pɣ t tp tw tɣ u ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor
# 		(1-2) Vpl -> -cor, rt -> Vpl
# 		(1-3) Vpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) -frnt
# 		(2-2) rt -> -frnt
# 		(2-3) rt -> -frnt, rt -> Pl
# 	226. [ t tj tp tɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> -dors, Cpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +cor, rt -> -rnd, rt -> Pl
# 	227. [ kt t tj tɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> +cor, Pl -> -lab, rt -> -rnd, rt -> Pl
# 	228. [ i kj pj tj y ]
# 		Defining factors:
# 		(1-1) Vpl -> +cor
# 		(1-2) Vpl -> +cor, Vpl -> -dors
# 		(1-3) Vpl -> +cor, rt -> Vpl
# 		(1-4) Vpl -> +cor, Vpl -> -dors, rt -> Vpl
# 		(1-5) Vpl -> +cor, rt -> Cpl, rt -> Vpl
# 		(1-6) Vpl -> +cor, Vpl -> -dors, rt -> Cpl, rt -> Vpl
# 		(2-1) +frnt
# 		(2-2) rt -> +frnt
# 		(2-3) rt -> Pl, rt -> +frnt
# 		(2-4) rt -> -bck, rt -> +frnt
# 		(2-5) rt -> -bck, rt -> Pl, rt -> +frnt
# 	229. [ kw pw ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> +rnd, rt -> Pl
# 	230. [ t tj tɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Cpl -> -dors, Cpl -> +cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +cor, Pl -> -lab, rt -> -rnd, rt -> Pl
# 	231. [ y ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> +lab, Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, Pl -> -lab, rt -> -bck, rt -> +rnd, rt -> Pl
# 	232. [ k kp kw kɣ p pw pɣ u ɨ ɯ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -cor, rt -> -frnt, rt -> Pl
# 	233. [ k kw ɨ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> -bck, rt -> Pl
# 	234. [ p pw pɣ ]
# 		Defining factors:
# 		(1-1) Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> +lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> +lab, Pl -> -cor, rt -> -frnt, rt -> Pl
# 	235. [ u ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> +dors, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> +dors, Vpl -> -cor, Cpl -> -dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -lab, Pl -> -cor, rt -> +bck, rt -> Pl
# 		(2-2) Pl -> -dors, Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> Pl
# 	236. [ i pj ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +cor, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +cor, Vpl -> -dors, Cpl -> -dors, Cpl -> -cor, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -dors, Pl -> -cor, rt -> -rnd, rt -> Pl, rt -> +frnt
# 		(2-2) Pl -> -dors, Pl -> -cor, rt -> -bck, rt -> -rnd, rt -> Pl, rt -> +frnt
# 	237. [ kɣ ɯ ]
# 		Defining factors:
# 		(1-1) Vpl -> -lab, Vpl -> +dors, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(1-2) Vpl -> -lab, Vpl -> +dors, Vpl -> -cor, Cpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, Pl -> -cor, rt -> +bck, rt -> -rnd, rt -> Pl
# 		(2-2) Pl -> -lab, Pl -> -cor, rt -> -frnt, rt -> +bck, rt -> -rnd, rt -> Pl
# 	238. [ k kt kw t tw ɨ ʉ ]
# 		Defining factors:
# 		(1-1) Vpl -> -dors, Vpl -> -cor, Cpl -> -lab, rt -> Cpl, rt -> Vpl
# 		(2-1) Pl -> -lab, rt -> -frnt, rt -> -bck, rt -> Pl
