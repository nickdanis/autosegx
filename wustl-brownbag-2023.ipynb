# %%
import autosegx as ax

unified_f = {
    'p' : {('rt','Cpl'), ('Cpl','+lab'), ('Cpl','-dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','-dors'), ('Vpl','-cor')},
    't' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','-dors'), ('Cpl','+cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','-dors'), ('Vpl','-cor')},
    'k' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','+dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','-dors'), ('Vpl','-cor')},
    'pw' : {('rt','Cpl'), ('Cpl','+lab'), ('Cpl','-dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','+lab'), ('Vpl','-dors'), ('Vpl','-cor')},
    'tw' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','-dors'), ('Cpl','+cor'), ('rt','Vpl'), ('Vpl','+lab'), ('Vpl','-dors'), ('Vpl','-cor')},
    'kw' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','+dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','+lab'), ('Vpl','-dors'), ('Vpl','-cor')},
    'pj' : {('rt','Cpl'), ('Cpl','+lab'), ('Cpl','-dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','-dors'), ('Vpl','+cor')},
    'tj' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','-dors'), ('Cpl','+cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','-dors'), ('Vpl','+cor')},
    'kj' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','+dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','-dors'), ('Vpl','+cor')},
    'pɣ' : {('rt','Cpl'), ('Cpl','+lab'), ('Cpl','-dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','+dors'), ('Vpl','-cor')},
    'tɣ' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','-dors'), ('Cpl','+cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','+dors'), ('Vpl','-cor')},
    'kɣ' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','+dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','+dors'), ('Vpl','-cor')},
    'kp' : {('rt','Cpl'), ('Cpl','+lab'), ('Cpl','+dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','-dors'), ('Vpl','-cor')},
    'tp' : {('rt','Cpl'), ('Cpl','+lab'), ('Cpl','-dors'), ('Cpl','+cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','-dors'), ('Vpl','-cor')},
    'kt' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','+dors'), ('Cpl','+cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','-dors'), ('Vpl','-cor')},
    'y' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','-dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','+lab'), ('Vpl','-dors'), ('Vpl','+cor')}, 
    'ʉ' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','-dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','+lab'), ('Vpl','-dors'), ('Vpl','-cor')},
    'u' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','-dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','+lab'), ('Vpl','+dors'), ('Vpl','-cor')},
    'i' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','-dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','-dors'), ('Vpl','+cor')},
    'ɨ' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','-dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','-dors'), ('Vpl','-cor')},
    'ɯ' : {('rt','Cpl'), ('Cpl','-lab'), ('Cpl','-dors'), ('Cpl','-cor'), ('rt','Vpl'), ('Vpl','-lab'), ('Vpl','+dors'), ('Vpl','-cor')},
}

v_features_f = {
    'p' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    't' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'k' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'pw' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','-frnt')},
    'tw' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','-frnt')},
    'kw' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','-frnt')},
    'pj' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','+frnt')},
    'tj' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','+frnt')},
    'kj' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','+frnt')},
    'pɣ' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','+bck'), ('rt','-frnt')},
    'tɣ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','+bck'), ('rt','-frnt')},
    'kɣ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','+bck'), ('rt','-frnt')},
    'kp' : {('rt','Pl'), ('Pl','+lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'tp' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'kt' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'y' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','+frnt')}, 
    'ʉ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','-frnt')},
    'u' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','+bck'), ('rt','-frnt')},
    'i' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','+frnt')},
    'ɨ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'ɯ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','+bck'), ('rt','-frnt')},
}

# %%
unified = ax.Theory(unified_f)

v_features = ax.Theory(v_features_f)

ax.compare_theories(unified, v_features, verbose=2)
# Out:
# The theories are NOT natural class preserving
# nat. classes      T1      T2
#       unique       6     158
#       shared      80      80
#        total      86     238
# Natural classes unique to T1:
# 1. ('i', 'kj', 'kt', 'pj', 't', 'tj', 'tp', 'tw', 'tɣ', 'y')
# 	 ['+cor']
# 2. ('i', 'k', 'kj', 'kp', 'kt', 'kw', 'kɣ', 'p', 'pj', 'pw', 'pɣ', 't', 'tp', 'tw', 'tɣ', 'u', 'y', 'ɨ', 'ɯ', 'ʉ')
# 	 ['-cor']
# 3. ('i', 'k', 'kj', 'kp', 'kt', 'kw', 'p', 'pj', 'pw', 'pɣ', 't', 'tj', 'tp', 'tw', 'tɣ', 'u', 'y', 'ɨ', 'ɯ', 'ʉ')
# 	 ['-dors']
# 4. ('kp', 'kw', 'p', 'pj', 'pw', 'pɣ', 'tp', 'tw', 'u', 'y', 'ʉ')
# 	 ['+lab']
# 5. ('k', 'kj', 'kp', 'kt', 'kw', 'kɣ', 'pɣ', 'tɣ', 'u', 'ɯ')
# 	 ['+dors']
# 6. ('i', 'k', 'kj', 'kp', 'kt', 'kw', 'kɣ', 'p', 'pj', 'pɣ', 't', 'tj', 'tp', 'tw', 'tɣ', 'u', 'y', 'ɨ', 'ɯ', 'ʉ')
# 	 ['-lab']
# Natural classes unique to T2:
# 1. ('kp', 'p', 'pj', 'pɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '+lab'), ('Pl', '-cor')]
# 2. ('k', 'kp', 'p', 'ɨ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-cor')]
# 3. ('i', 't', 'tj', 'tw', 'y', 'ɨ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '-lab'), ('Pl', '-dors')]
# 4. ('t', 'tj', 'tw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '-lab'), ('Pl', '+cor'), ('Pl', '-dors')]
# 5. ('t', 'ɨ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-dors')]
# 6. ('k', 'kj', 'kt', 'kw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '+dors'), ('Pl', '-lab')]
# 7. ('kt', 't', 'tw', 'tɣ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '+cor')]
# 8. ('i', 'y')
# 	 [('rt', 'Pl'), ('rt', '+frnt'), ('Pl', '-cor'), ('Pl', '-dors'), ('Pl', '-lab')]
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '+frnt'), ('Pl', '-cor'), ('Pl', '-dors'), ('Pl', '-lab')]
# 9. ('kɣ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+bck'), ('Pl', '-lab'), ('Pl', '-cor')]
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+bck'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-cor')]
# 10. ('k', 'kp', 'kt')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+dors')]
# 11. ('p', 'pw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+lab'), ('Pl', '-dors'), ('Pl', '-cor')]
# 12. ('kt', 't', 'tj')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '-lab'), ('Pl', '+cor')]
# 13. ('kw', 'tw', 'u', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-frnt'), ('Pl', '-lab')]
# 14. ('kɣ', 'pɣ', 'u', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '+bck'), ('Pl', '-cor')]
# 	 [('rt', 'Pl'), ('rt', '+bck'), ('rt', '-frnt'), ('Pl', '-cor')]
# 15. ('kp', 'p')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+lab'), ('Pl', '-cor')]
# 16. ('p', 'pɣ', 't', 'tp', 'tɣ', 'ɨ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '-dors')]
# 17. ('i', 'k', 'kj', 'kw', 'y', 'ɨ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '-lab'), ('Pl', '-cor')]
# 18. ('k', 'kw', 'kɣ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '+dors'), ('Pl', '-lab'), ('Pl', '-cor')]
# 19. ('k', 'kw', 'kɣ', 'u', 'ɨ', 'ɯ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-cor')]
# 20. ('i', 'ɨ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '-cor'), ('Pl', '-dors'), ('Pl', '-lab')]
# 21. ('k', 'kj', 'kp', 'kt', 'kɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '+dors')]
# 22. ('t', 'tp', 'tɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '+cor'), ('Pl', '-dors')]
# 23. ('kw', 'tw', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-lab')]
# 24. ('p', 'pj')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '+lab'), ('Pl', '-dors'), ('Pl', '-cor')]
# 25. ('k', 'kp', 'kt', 'kɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '+dors')]
# 26. ('i', 'tj', 'y')
# 	 [('rt', 'Pl'), ('rt', '+frnt'), ('Pl', '-dors'), ('Pl', '-lab')]
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '+frnt'), ('Pl', '-dors'), ('Pl', '-lab')]
# 27. ('k', 'kw', 'ɨ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-cor')]
# 28. ('kw', 'pw', 'u', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-frnt'), ('Pl', '-cor')]
# 29. ('ɨ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-dors'), ('Pl', '-cor')]
# 30. ('k', 'kt', 'kw', 'kɣ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '+dors'), ('Pl', '-lab')]
# 31. ('kw', 'pw', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-cor')]
# 32. ('p', 'pj', 'pɣ', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '+lab'), ('Pl', '-dors')]
# 33. ('i', 'k', 'kj', 'kp', 'kw', 'p', 'pj', 'pw', 'y', 'ɨ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '-cor')]
# 34. ('k', 'kt', 'kɣ', 't', 'tɣ', 'ɨ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '-lab')]
# 35. ('kt', 't', 'tw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '+cor')]
# 36. ('i', 'kj', 'pj')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+frnt'), ('Pl', '-cor')]
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '+frnt'), ('Pl', '-cor')]
# 37. ('pw', 'tw', 'u', 'y', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('Pl', '-dors')]
# 38. ('t', 'tp', 'tw', 'tɣ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '+cor'), ('Pl', '-dors')]
# 39. ('t', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+cor'), ('Pl', '-dors')]
# 40. ('p', 'pw', 't', 'tp', 'tw', 'ɨ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-dors')]
# 41. ('i', 'k', 'kj', 'kt', 'kw', 't', 'tj', 'tw', 'y', 'ɨ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '-lab')]
# 42. ('t', 'tj', 'tp', 'tɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '+cor'), ('Pl', '-dors')]
# 43. ('k', 'kj', 'kɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '+dors'), ('Pl', '-lab'), ('Pl', '-cor')]
# 44. ('k', 'kj', 'kp')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '+dors'), ('Pl', '-cor')]
# 45. ('i', 'kj', 'tj')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+frnt'), ('Pl', '-lab')]
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '+frnt'), ('Pl', '-lab')]
# 46. ('kw', 'y', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-bck'), ('Pl', '-lab'), ('Pl', '-cor')]
# 47. ('pw', 'u', 'y', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('Pl', '-dors'), ('Pl', '-cor')]
# 48. ('k', 'kj')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '+dors'), ('Pl', '-lab'), ('Pl', '-cor')]
# 49. ('u', 'y', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('Pl', '-cor'), ('Pl', '-dors'), ('Pl', '-lab')]
# 50. ('k', 'kp', 'kt', 'kw', 'kɣ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '+dors')]
# 51. ('u', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '+bck'), ('Pl', '-lab'), ('Pl', '-dors'), ('Pl', '-cor')]
# 	 [('rt', 'Pl'), ('rt', '+bck'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-dors'), ('Pl', '-cor')]
# 52. ('k', 'kj', 'kp', 'kw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '+dors'), ('Pl', '-cor')]
# 53. ('i', 'k', 'kj', 'kp', 'p', 'pj', 'ɨ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '-cor')]
# 54. ('t', 'tɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '+cor'), ('Pl', '-dors')]
# 55. ('kt', 't', 'tp', 'tw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+cor')]
# 56. ('i', 'kj', 'tj', 'y')
# 	 [('rt', 'Pl'), ('rt', '+frnt'), ('Pl', '-lab')]
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '+frnt'), ('Pl', '-lab')]
# 57. ('k', 'kp', 'kɣ', 'p', 'pɣ', 'ɨ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '-cor')]
# 58. ('p', 'ɨ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-dors'), ('Pl', '-cor')]
# 59. ('p', 'pj', 'pw', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '+lab'), ('Pl', '-dors')]
# 60. ('i', 'p', 'pj', 'pɣ', 'ɨ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '-dors'), ('Pl', '-cor')]
# 61. ('u', 'ɨ', 'ɯ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-dors'), ('Pl', '-cor')]
# 62. ('pɣ', 'tɣ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+bck'), ('Pl', '-dors')]
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+bck'), ('rt', '-frnt'), ('Pl', '-dors')]
# 63. ('kp', 'p', 'pw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+lab'), ('Pl', '-cor')]
# 64. ('kt', 't', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+cor')]
# 65. ('p', 'pw', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+lab'), ('Pl', '-dors')]
# 66. ('pw', 'tw', 'y', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-bck'), ('Pl', '-dors')]
# 67. ('i', 'p', 'pj', 't', 'tj', 'tp', 'ɨ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '-dors')]
# 68. ('p', 'pw', 'pɣ', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '+lab'), ('Pl', '-dors')]
# 69. ('k', 'kj', 'kt', 'kɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '+dors'), ('Pl', '-lab')]
# 70. ('t', 'tw', 'tɣ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '+cor'), ('Pl', '-dors')]
# 71. ('k', 'ɨ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-cor')]
# 72. ('kw', 'u', 'y', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('Pl', '-lab'), ('Pl', '-cor')]
# 73. ('k', 'kt')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+dors'), ('Pl', '-lab')]
# 74. ('i', 'p', 'pj', 'pɣ', 't', 'tj', 'tp', 'tɣ', 'ɨ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '-dors')]
# 75. ('p', 'pj', 'pw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '+lab'), ('Pl', '-dors'), ('Pl', '-cor')]
# 76. ('tɣ', 'u', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '+bck'), ('Pl', '-lab'), ('Pl', '-dors')]
# 	 [('rt', 'Pl'), ('rt', '+bck'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-dors')]
# 77. ('kw', 'pw', 'u', 'y', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('Pl', '-cor')]
# 78. ('kp', 'p', 'pw', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+lab')]
# 79. ('k', 'kw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+dors'), ('Pl', '-lab'), ('Pl', '-cor')]
# 80. ('ɨ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-dors'), ('Pl', '-cor')]
# 81. ('kp', 'p', 'pj')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '+lab'), ('Pl', '-cor')]
# 82. ('k', 'kt', 'kw', 't', 'tw', 'ɨ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-lab')]
# 83. ('i', 'kj', 'y')
# 	 [('rt', 'Pl'), ('rt', '+frnt'), ('Pl', '-cor'), ('Pl', '-lab')]
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '+frnt'), ('Pl', '-cor'), ('Pl', '-lab')]
# 84. ('kt', 't', 'tj', 'tw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '-lab'), ('Pl', '+cor')]
# 85. ('t', 'tj', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '+cor'), ('Pl', '-dors')]
# 86. ('pw', 'tw', 'u', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-frnt'), ('Pl', '-dors')]
# 87. ('kw', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-cor')]
# 88. ('p', 'pw', 'pɣ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '+lab'), ('Pl', '-dors'), ('Pl', '-cor')]
# 89. ('kt', 't', 'tj', 'tp', 'tw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '+cor')]
# 90. ('p', 'pɣ', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '+lab'), ('Pl', '-dors')]
# 91. ('p', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+lab'), ('Pl', '-dors')]
# 92. ('tw', 'u', 'y', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('Pl', '-lab'), ('Pl', '-dors')]
# 93. ('y', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-bck'), ('Pl', '-cor'), ('Pl', '-dors'), ('Pl', '-lab')]
# 94. ('i', 'k', 'kj', 'kt', 't', 'tj', 'ɨ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '-lab')]
# 95. ('k', 'kt', 't', 'ɨ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-lab')]
# 96. ('p', 't', 'tp', 'ɨ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-dors')]
# 97. ('p', 'pɣ', 'ɨ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '-dors'), ('Pl', '-cor')]
# 98. ('kp', 'p', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+lab')]
# 99. ('i', 'k', 'kj', 'ɨ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '-lab'), ('Pl', '-cor')]
# 100. ('k', 'kt', 'kw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+dors'), ('Pl', '-lab')]
# 101. ('p', 'pw', 'pɣ', 'u', 'ɨ', 'ɯ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '-dors'), ('Pl', '-cor')]
# 102. ('i', 'y', 'ɨ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '-cor'), ('Pl', '-dors'), ('Pl', '-lab')]
# 103. ('u', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-dors'), ('Pl', '-cor')]
# 104. ('kp', 'p', 'pj', 'pw', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '+lab')]
# 105. ('t', 'tw', 'tɣ', 'u', 'ɨ', 'ɯ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-dors')]
# 106. ('t', 'tj', 'tɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '-lab'), ('Pl', '+cor'), ('Pl', '-dors')]
# 107. ('kɣ', 'tɣ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+bck'), ('Pl', '-lab')]
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+bck'), ('rt', '-frnt'), ('Pl', '-lab')]
# 108. ('kɣ', 'tɣ', 'u', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '+bck'), ('Pl', '-lab')]
# 	 [('rt', 'Pl'), ('rt', '+bck'), ('rt', '-frnt'), ('Pl', '-lab')]
# 109. ('i', 'tj')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+frnt'), ('Pl', '-dors'), ('Pl', '-lab')]
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '+frnt'), ('Pl', '-dors'), ('Pl', '-lab')]
# 110. ('pɣ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+bck'), ('Pl', '-dors'), ('Pl', '-cor')]
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+bck'), ('rt', '-frnt'), ('Pl', '-dors'), ('Pl', '-cor')]
# 111. ('pw', 'y', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-bck'), ('Pl', '-dors'), ('Pl', '-cor')]
# 112. ('i', 'p', 'pj', 'ɨ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '-dors'), ('Pl', '-cor')]
# 113. ('i', 't', 'tj', 'tɣ', 'ɨ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '-lab'), ('Pl', '-dors')]
# 114. ('t', 'tɣ', 'ɨ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-dors')]
# 115. ('tw', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-dors')]
# 116. ('p', 'pɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '+lab'), ('Pl', '-dors'), ('Pl', '-cor')]
# 117. ('pw', 'u', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-frnt'), ('Pl', '-dors'), ('Pl', '-cor')]
# 118. ('k', 'kj', 'kp', 'kɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '+dors'), ('Pl', '-cor')]
# 119. ('i', 'pj', 'tj', 'y')
# 	 [('rt', 'Pl'), ('rt', '+frnt'), ('Pl', '-dors')]
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '+frnt'), ('Pl', '-dors')]
# 120. ('pw', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-dors'), ('Pl', '-cor')]
# 121. ('k', 'kt', 'kw', 'kɣ', 't', 'tw', 'tɣ', 'u', 'ɨ', 'ɯ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '-lab')]
# 122. ('i', 'ɨ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '-cor'), ('Pl', '-dors'), ('Pl', '-lab')]
# 123. ('kt', 't')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '+cor')]
# 124. ('t', 'tj', 'tp', 'tw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '+cor'), ('Pl', '-dors')]
# 125. ('kp', 'p', 'pj', 'pw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '+lab'), ('Pl', '-cor')]
# 126. ('kt', 't', 'tj', 'tp', 'tɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '+cor')]
# 127. ('tw', 'u', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-dors')]
# 128. ('kw', 'tw', 'y', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-bck'), ('Pl', '-lab')]
# 129. ('t', 'tw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '+cor'), ('Pl', '-dors')]
# 130. ('i', 'pj')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+frnt'), ('Pl', '-cor'), ('Pl', '-dors')]
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '+frnt'), ('Pl', '-cor'), ('Pl', '-dors')]
# 131. ('k', 'kɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '+dors'), ('Pl', '-lab'), ('Pl', '-cor')]
# 132. ('k', 'kp')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+dors'), ('Pl', '-cor')]
# 133. ('k', 'kp', 'kw', 'p', 'pw', 'ɨ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-cor')]
# 134. ('t', 'tw', 'ɨ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-dors')]
# 135. ('k', 'kp', 'kt', 'kw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '+dors')]
# 136. ('i', 'pj', 'tj')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+frnt'), ('Pl', '-dors')]
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('rt', '+frnt'), ('Pl', '-dors')]
# 137. ('kp', 'p', 'pw', 'pɣ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '+lab'), ('Pl', '-cor')]
# 138. ('kp', 'p', 'pɣ', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '+lab')]
# 139. ('kt', 't', 'tp', 'tɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '+cor')]
# 140. ('k', 'kj', 'kp', 'kt')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '+dors')]
# 141. ('k', 'kp', 'kɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '+dors'), ('Pl', '-cor')]
# 142. ('kw', 'pw', 'y', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-bck'), ('Pl', '-cor')]
# 143. ('k', 'kj', 'kw')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '+dors'), ('Pl', '-lab'), ('Pl', '-cor')]
# 144. ('kp', 'p', 'pw', 'pɣ', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '+lab')]
# 145. ('k', 'kt', 'kɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-frnt'), ('Pl', '+dors'), ('Pl', '-lab')]
# 146. ('kɣ', 'u', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '+bck'), ('Pl', '-lab'), ('Pl', '-cor')]
# 	 [('rt', 'Pl'), ('rt', '+bck'), ('rt', '-frnt'), ('Pl', '-lab'), ('Pl', '-cor')]
# 147. ('kp', 'p', 'pj', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '+lab')]
# 148. ('i', 'p', 'pj', 'pw', 'y', 'ɨ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-bck'), ('Pl', '-dors'), ('Pl', '-cor')]
# 149. ('kt', 't', 'tj', 'tp')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '+cor')]
# 150. ('i', 'k', 'kj', 'kɣ', 'ɨ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '-lab'), ('Pl', '-cor')]
# 151. ('t', 'tj')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '-bck'), ('Pl', '-lab'), ('Pl', '+cor'), ('Pl', '-dors')]
# 152. ('kɣ', 'pɣ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+bck'), ('Pl', '-cor')]
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('rt', '+bck'), ('rt', '-frnt'), ('Pl', '-cor')]
# 153. ('k', 'kp', 'kw', 'kɣ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '+dors'), ('Pl', '-cor')]
# 154. ('p', 'pj', 'pɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '+lab'), ('Pl', '-dors'), ('Pl', '-cor')]
# 155. ('pw', 'tw', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '+rnd'), ('rt', '-bck'), ('rt', '-frnt'), ('Pl', '-dors')]
# 156. ('kt', 't', 'tj', 'tɣ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '-lab'), ('Pl', '+cor')]
# 157. ('p', 'pw', 'pɣ', 't', 'tp', 'tw', 'tɣ', 'u', 'ɨ', 'ɯ', 'ʉ')
# 	 [('rt', 'Pl'), ('rt', '-frnt'), ('Pl', '-dors')]
# 158. ('i', 'k', 'kj', 'kp', 'kɣ', 'p', 'pj', 'pɣ', 'ɨ', 'ɯ')
# 	 [('rt', 'Pl'), ('rt', '-rnd'), ('Pl', '-cor')]
# False
