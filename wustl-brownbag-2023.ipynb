# %%
import autosegx as ax

unified_f = {
    'p' : {('rt','Cpl'), ('Cpl','+lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    't' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','+cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'k' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','+dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'pw' : {('rt','Cpl'), ('Cpl','+lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','+lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'tw' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','+cor1'), ('rt','Vpl'), ('Vpl','+lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'kw' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','+dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','+lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'pj' : {('rt','Cpl'), ('Cpl','+lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','+cor2')},
    'tj' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','+cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','+cor2')},
    'kj' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','+dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','+cor2')},
    'pɣ' : {('rt','Cpl'), ('Cpl','+lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','+dors2'), ('Vpl','-cor2')},
    'tɣ' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','+cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','+dors2'), ('Vpl','-cor2')},
    'kɣ' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','+dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','+dors2'), ('Vpl','-cor2')},
    'kp' : {('rt','Cpl'), ('Cpl','+lab1'), ('Cpl','+dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'tp' : {('rt','Cpl'), ('Cpl','+lab1'), ('Cpl','-dors1'), ('Cpl','+cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'kt' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','+dors1'), ('Cpl','+cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'y' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','+lab2'), ('Vpl','-dors2'), ('Vpl','+cor2')}, 
    'ʉ' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','+lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'u' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','+lab2'), ('Vpl','+dors2'), ('Vpl','-cor2')},
    'i' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','+cor2')},
    'ɨ' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor2')},
    'ɯ' : {('rt','Cpl'), ('Cpl','-lab1'), ('Cpl','-dors1'), ('Cpl','-cor1'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','+dors2'), ('Vpl','-cor2')},
}

v_features_f = {
    'p' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    't' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'k' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'pw' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','-frnt')},
    'tw' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','-frnt')},
    'kw' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','-frnt')},
    'pj' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','+frnt')},
    'tj' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','+frnt')},
    'kj' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','+frnt')},
    'pɣ' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','+bck'), ('rt','-frnt')},
    'tɣ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','+bck'), ('rt','-frnt')},
    'kɣ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','+bck'), ('rt','-frnt')},
    'kp' : {('rt','Pl'), ('Pl','+lab'), ('Pl','+dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'tp' : {('rt','Pl'), ('Pl','+lab'), ('Pl','-dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'kt' : {('rt','Pl'), ('Pl','-lab'), ('Pl','+dors'), ('Pl','+cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'y' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','+frnt')}, 
    'ʉ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','-bck'), ('rt','-frnt')},
    'u' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','+rnd'), ('rt','+bck'), ('rt','-frnt')},
    'i' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','+frnt')},
    'ɨ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','-bck'), ('rt','-frnt')},
    'ɯ' : {('rt','Pl'), ('Pl','-lab'), ('Pl','-dors'), ('Pl','-cor'), ('rt','-rnd'), ('rt','+bck'), ('rt','-frnt')},
}

# %%
unified = ax.Theory(unified_f)

v_features = ax.Theory(v_features_f)

ax.compare_theories(unified, v_features, verbose=2)
# Out:
# The theories are NOT natural class preserving
# nat. classes      T1      T2
#       unique       6       0
#       shared     238     238
#        total     244     238
# Natural classes unique to T1:
# 1. ('kp', 'kw', 'p', 'pj', 'pw', 'pɣ', 'tp', 'tw', 'u', 'y', 'ʉ')
# 	 [('+lab1', '+lab')]
# 2. ('k', 'kj', 'kp', 'kt', 'kw', 'kɣ', 'pɣ', 'tɣ', 'u', 'ɯ')
# 	 [('+dors1', '+dors')]
# 3. ('i', 'kj', 'kt', 'pj', 't', 'tj', 'tp', 'tw', 'tɣ', 'y')
# 	 [('+cor1', '+cor')]
# 4. ('i', 'k', 'kj', 'kp', 'kt', 'kw', 'kɣ', 'p', 'pj', 'pw', 'pɣ', 't', 'tp', 'tw', 'tɣ', 'u', 'y', 'ɨ', 'ɯ', 'ʉ')
# 	 [('-cor2', '-cor')]
# 5. ('i', 'k', 'kj', 'kp', 'kt', 'kw', 'p', 'pj', 'pw', 'pɣ', 't', 'tj', 'tp', 'tw', 'tɣ', 'u', 'y', 'ɨ', 'ɯ', 'ʉ')
# 	 [('-dors1', '-dors')]
# 6. ('i', 'k', 'kj', 'kp', 'kt', 'kw', 'kɣ', 'p', 'pj', 'pɣ', 't', 'tj', 'tp', 'tw', 'tɣ', 'u', 'y', 'ɨ', 'ɯ', 'ʉ')
# 	 [('-lab2', '-lab')]
# Shared natural classes:
# 1. ('k', 'kj', 'kp', 'kt', 'kw')
# 2. ('i', 't', 'tj', 'tw', 'y', 'ɨ', 'ʉ')
# 3. ('k', 'kp', 'kt', 'kw', 'kɣ')
# 4. ('i', 'kj', 'pj')
# 5. ('tɣ', 'u', 'ɯ')
# 6. ('kt', 't', 'tj', 'tw', 'tɣ')
# 7. ('pw', 'tw', 'ʉ')
# 8. ('tp',)
# 9. ('k', 'kw')
# 10. ('i', 'kj', 'y')
# 11. ('t', 'tɣ', 'ɨ', 'ɯ')
# 12. ('t', 'ɨ')
# 13. ('kp', 'p', 'pj', 'pw', 'tp')
# 14. ('p', 'pj', 'pɣ', 'tp')
# 15. ('k', 'kp', 'kw', 'kɣ')
# 16. ('i', 'k', 'kj', 'kp', 'kɣ', 'p', 'pj', 'pɣ', 'ɨ', 'ɯ')
# 17. ('kw', 'pw', 'tw', 'ʉ')
# 18. ('pw', 'y', 'ʉ')
# 19. ('i', 'k', 'kj', 'kp', 'kw', 'kɣ', 'p', 'pj', 'pw', 'pɣ', 'u', 'y', 'ɨ', 'ɯ', 'ʉ')
# 20. ('p', 'pj')
# 21. ('u', 'ɨ', 'ɯ', 'ʉ')
# 22. ('kt', 't', 'tw', 'tɣ')
# 23. ('t', 'tj', 'tɣ')
# 24. ('pɣ', 'ɯ')
# 25. ('t', 'tp')
# 26. ('i', 'pj', 'y')
# 27. ('ɨ', 'ɯ')
# 28. ('k', 'kj', 'kp', 'kt', 'kw', 'kɣ')
# 29. ('i', 'k', 'kj', 'kt', 'kɣ', 't', 'tj', 'tɣ', 'ɨ', 'ɯ')
# 30. ('kɣ', 'pɣ', 'tɣ', 'ɯ')
# 31. ('t', 'tp', 'tw', 'tɣ')
# 32. ('kp', 'p', 'pw', 'pɣ')
# 33. ('kw', 'pw', 'u', 'ʉ')
# 34. ('i', 'k', 'kj', 'kw', 'y', 'ɨ', 'ʉ')
# 35. ('i', 'k', 'kj', 'kp', 'kt', 'kw', 'kɣ', 'p', 'pj', 'pw', 'pɣ', 't', 'tj', 'tp', 'tw', 'tɣ', 'u', 'y', 'ɨ', 'ɯ', 'ʉ')
# 36. ('i', 'p', 'pj', 'pw', 'y', 'ɨ', 'ʉ')
# 37. ('tw',)
# 38. ('i', 'tj')
# 39. ('kt', 't', 'tj', 'tɣ')
# 40. ('kt', 't', 'tw')
# 41. ('kp', 'p', 'pj', 'tp')
# 42. ('kw', 'pw', 'ʉ')
# 43. ('k', 'kj', 'kp', 'kw')
# 44. ('k', 'kɣ')
# 45. ('i', 'pj')
# 46. ('i', 'k', 'kj', 'kw', 'kɣ', 'u', 'y', 'ɨ', 'ɯ', 'ʉ')
# 47. ('k', 'kw', 'kɣ', 'u', 'ɨ', 'ɯ', 'ʉ')
# 48. ('i', 'kj')
# 49. ('p', 'pɣ', 'tp')
# 50. ('i', 'y')
# 51. ('kɣ', 'pɣ', 'ɯ')
# 52. ('t', 'tw')
# 53. ('i', 'p', 'pj', 'pw', 't', 'tj', 'tp', 'tw', 'y', 'ɨ', 'ʉ')
# 54. ('k', 'kp', 'kw', 'kɣ', 'p', 'pw', 'pɣ', 'u', 'ɨ', 'ɯ', 'ʉ')
# 55. ('tj',)
# 56. ('kp',)
# 57. ('kp', 'p', 'pj')
# 58. ('k', 'kj', 'kw')
# 59. ('i', 'kj', 'pj', 'tj', 'y')
# 60. ('t', 'tj', 'tp', 'tɣ')
# 61. ('y', 'ʉ')
# 62. ('kt', 't', 'tj')
# 63. ('kw', 'u', 'ʉ')
# 64. ('pɣ', 'u', 'ɯ')
# 65. ('kj',)
# 66. ('ɨ',)
# 67. ('i', 'k', 'kj', 'kp', 'kt', 'kɣ', 'p', 'pj', 'pɣ', 't', 'tj', 'tp', 'tɣ', 'ɨ', 'ɯ')
# 68. ('i', 'k', 'kj', 'kp', 'kt', 'kw', 'p', 'pj', 'pw', 't', 'tj', 'tp', 'tw', 'y', 'ɨ', 'ʉ')
# 69. ('t', 'tw', 'tɣ', 'u', 'ɨ', 'ɯ', 'ʉ')
# 70. ('kw', 'tw', 'u', 'ʉ')
# 71. ('k', 'kɣ', 'ɨ', 'ɯ')
# 72. ('u', 'ɯ')
# 73. ('t', 'tj')
# 74. ('i', 'pj', 'tj', 'y')
# 75. ('p', 'pw')
# 76. ('i', 'u', 'y', 'ɨ', 'ɯ', 'ʉ')
# 77. ('kp', 'p', 'pw', 'tp')
# 78. ('k', 'kj', 'kp', 'kɣ')
# 79. ('p', 'pj', 'pw', 'pɣ')
# 80. ('t', 'tj', 'tp')
# 81. ('pw', 'u', 'y', 'ʉ')
# 82. ('k', 'kj', 'kt', 'kw')
# 83. ('k', 'kp', 'kt')
# 84. ('pɣ', 'tɣ', 'ɯ')
# 85. ('kp', 'p', 'pw', 'pɣ', 'tp')
# 86. ('p', 'pw', 't', 'tp', 'tw', 'ɨ', 'ʉ')
# 87. ('kɣ', 'pɣ', 'u', 'ɯ')
# 88. ('kt', 't', 'tp', 'tɣ')
# 89. ('ɨ', 'ʉ')
# 90. ('k', 'kj', 'kɣ')
# 91. ('kt', 't', 'tj', 'tp', 'tw')
# 92. ('i', 't', 'tj', 'ɨ')
# 93. ('kt', 't', 'tj', 'tp')
# 94. ('pw', 'u', 'ʉ')
# 95. ('p', 'pɣ', 't', 'tp', 'tɣ', 'ɨ', 'ɯ')
# 96. ('i', 't', 'tj', 'tw', 'tɣ', 'u', 'y', 'ɨ', 'ɯ', 'ʉ')
# 97. ('i', 'p', 'pj', 'pɣ', 'ɨ', 'ɯ')
# 98. ('kt',)
# 99. ('i', 'y', 'ɨ', 'ʉ')
# 100. ('k', 'kt', 'kw', 'kɣ', 't', 'tw', 'tɣ', 'u', 'ɨ', 'ɯ', 'ʉ')
# 101. ('p', 'pw', 'pɣ', 'tp')
# 102. ('p',)
# 103. ('k', 'kt', 'kw')
# 104. ('kt', 't', 'tj', 'tp', 'tw', 'tɣ')
# 105. ('k', 'kj', 'kp', 'kt', 'kɣ')
# 106. ('kw', 'pw', 'tw', 'u', 'ʉ')
# 107. ('p', 'pw', 'pɣ')
# 108. ('k', 'kt', 'kɣ', 't', 'tɣ', 'ɨ', 'ɯ')
# 109. ('p', 'pj', 'pw')
# 110. ('t', 'tj', 'tw')
# 111. ('p', 'pw', 'ɨ', 'ʉ')
# 112. ('p', 'pw', 'pɣ', 'u', 'ɨ', 'ɯ', 'ʉ')
# 113. ('kp', 'p')
# 114. ('p', 'pɣ')
# 115. ('k', 'kp')
# 116. ('tw', 'u', 'y', 'ʉ')
# 117. ('tw', 'u', 'ʉ')
# 118. ('kp', 'p', 'pw')
# 119. ('i', 't', 'tj', 'tɣ', 'ɨ', 'ɯ')
# 120. ('i', 'p', 'pj', 'ɨ')
# 121. ('k', 'kj', 'kt', 'kɣ')
# 122. ('k', 'ɨ')
# 123. ('k', 'kj')
# 124. ('kt', 't', 'tj', 'tw')
# 125. ('k', 'kt', 't', 'ɨ')
# 126. ('i', 'k', 'kj', 'kp', 'kw', 'p', 'pj', 'pw', 'y', 'ɨ', 'ʉ')
# 127. ('i', 'kj', 'tj', 'y')
# 128. ('i', 'kj', 'pj', 'tj')
# 129. ('t', 'tj', 'tw', 'tɣ')
# 130. ('pw', 'tw', 'u', 'ʉ')
# 131. ('p', 'pj', 'pw', 'tp')
# 132. ('k', 'kt', 'kw', 'kɣ')
# 133. ('k', 'kp', 'kt', 'kw', 'kɣ', 'p', 'pw', 'pɣ', 't', 'tp', 'tw', 'tɣ', 'u', 'ɨ', 'ɯ', 'ʉ')
# 134. ('kɣ', 'tɣ', 'u', 'ɯ')
# 135. ('t', 'tp', 'tɣ')
# 136. ('kw', 'pw', 'u', 'y', 'ʉ')
# 137. ('pj',)
# 138. ('i', 'kj', 'pj', 'y')
# 139. ('y',)
# 140. ('t', 'tw', 'ɨ', 'ʉ')
# 141. ('i', 'p', 'pj', 'pw', 'pɣ', 'u', 'y', 'ɨ', 'ɯ', 'ʉ')
# 142. ('t', 'tj', 'tp', 'tw')
# 143. ('i', 'tj', 'y')
# 144. ('i', 'p', 'pj', 'pw', 'pɣ', 't', 'tj', 'tp', 'tw', 'tɣ', 'u', 'y', 'ɨ', 'ɯ', 'ʉ')
# 145. ('kw', 'pw', 'y', 'ʉ')
# 146. ('i', 'k', 'kj', 'kt', 'kw', 't', 'tj', 'tw', 'y', 'ɨ', 'ʉ')
# 147. ('i', 'p', 'pj', 't', 'tj', 'tp', 'ɨ')
# 148. ('kp', 'p', 'pɣ')
# 149. ('p', 'pw', 'tp')
# 150. ('i', 'k', 'kj', 'kt', 't', 'tj', 'ɨ')
# 151. ('k', 'kt')
# 152. ('ɯ',)
# 153. ('p', 'pɣ', 'ɨ', 'ɯ')
# 154. ('k', 'kj', 'kp')
# 155. ('tw', 'y', 'ʉ')
# 156. ('p', 'tp')
# 157. ('tɣ', 'ɯ')
# 158. ('i', 'k', 'kj', 'kt', 'kw', 'kɣ', 't', 'tj', 'tw', 'tɣ', 'u', 'y', 'ɨ', 'ɯ', 'ʉ')
# 159. ('k', 'kj', 'kw', 'kɣ')
# 160. ('i', 'k', 'kj', 'kp', 'kt', 'p', 'pj', 't', 'tj', 'tp', 'ɨ')
# 161. ('kp', 'p', 'pɣ', 'tp')
# 162. ('kt', 't', 'tp', 'tw')
# 163. ('pw', 'tw', 'y', 'ʉ')
# 164. ('kw', 'u', 'y', 'ʉ')
# 165. ('kɣ', 'u', 'ɯ')
# 166. ('k', 'kp', 'kt', 'p', 't', 'tp', 'ɨ')
# 167. ('kt', 't')
# 168. ('kp', 'p', 'pj', 'pɣ', 'tp')
# 169. ('kw', 'tw', 'u', 'y', 'ʉ')
# 170. ('kw', 'y', 'ʉ')
# 171. ('k', 'kw', 'kɣ')
# 172. ('i', 'k', 'kj', 'ɨ')
# 173. ('k', 'kj', 'kp', 'kt')
# 174. ('kt', 't', 'tp', 'tw', 'tɣ')
# 175. ('pw', 'ʉ')
# 176. ('p', 'pj', 'tp')
# 177. ('kɣ', 'ɯ')
# 178. ('t',)
# 179. ('pw',)
# 180. ('i', 'kj', 'tj')
# 181. ('kɣ', 'pɣ', 'tɣ', 'u', 'ɯ')
# 182. ('tw', 'ʉ')
# 183. ('kp', 'p', 'tp')
# 184. ('pw', 'tw', 'u', 'y', 'ʉ')
# 185. ('k', 'kj', 'kt')
# 186. ('t', 'tw', 'tɣ')
# 187. ('k', 'kp', 'kt', 'kw')
# 188. ('u',)
# 189. ('k', 'kp', 'kt', 'kw', 'p', 'pw', 't', 'tp', 'tw', 'ɨ', 'ʉ')
# 190. ('i', 'p', 'pj', 'pɣ', 't', 'tj', 'tp', 'tɣ', 'ɨ', 'ɯ')
# 191. ('kt', 't', 'tj', 'tp', 'tɣ')
# 192. ('k', 'kt', 'kɣ')
# 193. ('k', 'kp', 'kw')
# 194. ('kt', 't', 'tp')
# 195. ('k',)
# 196. ('i', 'pj', 'tj')
# 197. ('u', 'ʉ')
# 198. ('p', 'pj', 'pɣ')
# 199. ('k', 'kp', 'p', 'ɨ')
# 200. ('ʉ',)
# 201. ('t', 'tp', 'tw')
# 202. ('p', 'ɨ')
# 203. ('k', 'kp', 'kɣ', 'p', 'pɣ', 'ɨ', 'ɯ')
# 204. ('tɣ',)
# 205. ('p', 't', 'tp', 'ɨ')
# 206. ('kw',)
# 207. ('kt', 't', 'tɣ')
# 208. ('kw', 'pw', 'tw', 'y', 'ʉ')
# 209. ('k', 'kj', 'kp', 'kw', 'kɣ')
# 210. ('kp', 'p', 'pj', 'pw')
# 211. ('pɣ',)
# 212. ('k', 'kp', 'kt', 'kɣ', 'p', 'pɣ', 't', 'tp', 'tɣ', 'ɨ', 'ɯ')
# 213. ('k', 'kj', 'kt', 'kw', 'kɣ')
# 214. ('i', 'k', 'kj', 'kp', 'p', 'pj', 'ɨ')
# 215. ('kp', 'p', 'pj', 'pw', 'pɣ')
# 216. ('u', 'y', 'ʉ')
# 217. ('kw', 'pw', 'tw', 'u', 'y', 'ʉ')
# 218. ('t', 'tɣ')
# 219. ('k', 'kp', 'kt', 'kɣ')
# 220. ('kw', 'tw', 'ʉ')
# 221. ('kw', 'ʉ')
# 222. ('i', 'ɨ', 'ɯ')
# 223. ('k', 'kp', 'kɣ')
# 224. ('i', 'ɨ')
# 225. ('p', 'pw', 'pɣ', 't', 'tp', 'tw', 'tɣ', 'u', 'ɨ', 'ɯ', 'ʉ')
# 226. ('kɣ', 'tɣ', 'ɯ')
# 227. ('p', 'pj', 'pw', 'pɣ', 'tp')
# 228. ('pɣ', 'tɣ', 'u', 'ɯ')
# 229. ('k', 'kt', 'kw', 't', 'tw', 'ɨ', 'ʉ')
# 230. ('t', 'tj', 'tp', 'tw', 'tɣ')
# 231. ('k', 'kp', 'kw', 'p', 'pw', 'ɨ', 'ʉ')
# 232. ('kɣ',)
# 233. ('i',)
# 234. ('kp', 'p', 'pj', 'pw', 'pɣ', 'tp')
# 235. ('k', 'kw', 'ɨ', 'ʉ')
# 236. ('kp', 'p', 'pj', 'pɣ')
# 237. ('kw', 'tw', 'y', 'ʉ')
# 238. ('i', 'k', 'kj', 'kɣ', 'ɨ', 'ɯ')
# False

# %%
help(list(unified.nce.values())[6][0].draw_phono())
# Out:
# Help on NoneType object:
#
# class NoneType(object)
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
unified = ax.Theory(unified_f)
unified.segments['kp'].draw_phono()

# %%
kp_graph = [('rt','Cpl'), ('Cpl','+lab1'), ('Cpl','+dors1'), ('Cpl','-cor11'), ('rt','Vpl'), ('Vpl','-lab2'), ('Vpl','-dors2'), ('Vpl','-cor22')]
kp = ax.Segment()
kp.create_geometry(kp_graph)

# %%
kp.draw_phono()

# %%
mini_u = {'p' : {('rt','lab1'), ('rt','lab2')},
          'u' : {('rt','lab2'), ('rt','lab')}}

mini_f = {'p' : {('rt','lab')},
          'u' : {('rt','lab')}}

mini_uni = ax.Theory(mini_u)

mini_feat = ax.Theory(mini_f)

ax.compare_theories(mini_uni, mini_feat, verbose=2)
